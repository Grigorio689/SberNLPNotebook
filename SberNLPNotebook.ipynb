# %% [markdown]
# ## <center>Sberbank NLP Notebook</center>

# %% [markdown]
# #### Задача:
# <i>Обучить интерпретируемую NLP модель на массиве размеченных данных таким образом, чтобы точность предсказаний на тестовой выборке была максимальной (оптимизационная задача)</i>
#
# #### План:
#
# 1. Выбор датасета
# 2. Предобработка данных
# 3. Feature Engineering
# 4. Обучение моделей
# 5. Результаты и выводы

# %%
import pandas as pd 
import logging

# info logging setup 
logging.basicConfig(level=logging.INFO, format='%(asctime)s : %(levelname)s : %(message)s')
# Out:
# /home/greg/anaconda3/envs/py36_2/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/greg/anaconda3/envs/py36_2/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# ### 1. Выбор датасета
#
# В исследовании будет использован датасет Gender Classifier Data от Figure Eight (https://www.figure-eight.com/wp-content/uploads/2016/03/gender-classifier-DFE-791531.csv), содержащий 20050 объектов - пользователей Twitter - и предварительно размеченный вручную тремя экспертами на предмет пола каждого пользователя.
# Он же доступен на Kaggle (https://www.kaggle.com/crowdflower/twitter-user-gender-classification/home) с описаниями характеристик объектов:
#
# <b>_unit_id</b>: a unique id for user
# <br><b>_golden</b>: whether the user was included in the gold standard for the model; TRUE or FALSE
# <br><b>_unit_state</b>: state of the observation; one of finalized (for contributor-judged) or golden (for gold standard observations)
# <br><b>_trusted_judgments</b>: number of trusted judgments (int); always 3 for non-golden, and what may be a unique id for gold standard observations
# <br><b>_last_judgment_at</b>: date and time of last contributor judgment; blank for gold standard observations
# <br><b>gender</b>: one of male, female, or brand (for non-human profiles)
# <br><b>gender:confidence</b>: a float representing confidence in the provided gender
# <br><b>profile_yn</b>: "no" here seems to mean that the profile was meant to be part of the dataset but was not available when contributors went to judge it
# <br><b>profile_yn:confidence</b>: confidence in the existence/non-existence of the profile
# <br><b>created</b>: date and time when the profile was created
# <br><b>description</b>: the user's profile description
# <br><b>fav_number</b>: number of tweets the user has favorited
# <br><b>gender_gold</b>: if the profile is golden, what is the gender?
# <br><b>link_color</b>: the link color on the profile, as a hex value
# <br><b>name</b>: the user's name
# <br><b>profile_yn_gold</b>: whether the profile y/n value is golden
# <br><b>profileimage</b>: a link to the profile image
# <br><b>retweet_count</b>: number of times the user has retweeted (or possibly, been retweeted)
# <br><b>sidebar_color</b>: color of the profile sidebar, as a hex value
# <br><b>text</b>: text of a random one of the user's tweets
# <br><b>tweet_coord</b>: if the user has location turned on, the coordinates as a string with the format "[latitude, longitude]"
# <br><b>tweet_count</b>: number of tweets that the user has posted
# <br><b>tweet_created</b>: when the random tweet (in the text column) was created
# <br><b>tweet_id</b>: the tweet id of the random tweet
# <br><b>tweet_location</b>: location of the tweet; seems to not be particularly normalized
# <br><b>user_timezone</b>: the timezone of the user
#
# В рамках этого исследования будет производиться анализ только текстовой информации (текст случайного твита пользователя <b>text</b> и описание в его профиле <b>description</b>. Другие фичи в качестве надстройки над NLP не учавствуют.
#
# ### 2. Предобработка данных

# %%
# импорт csv файла в датафрейм 
# https://www.figure-eight.com/wp-content/uploads/2016/03/ --перед файлом в след. строке чтобы не качать отдельно 
df_raw = pd.read_csv("gender-classifier-DFE-791531.csv", encoding="ISO-8859-1")
df_raw
# Out:
#         _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0      815719226    False   finalized                   3    10/26/15 23:24
# 1      815719227    False   finalized                   3    10/26/15 23:30
# 2      815719228    False   finalized                   3    10/26/15 23:33
# 3      815719229    False   finalized                   3    10/26/15 23:10
# 4      815719230    False   finalized                   3     10/27/15 1:15
# 5      815719231    False   finalized                   3     10/27/15 1:47
# 6      815719232    False   finalized                   3     10/27/15 1:57
# 7      815719233    False   finalized                   3    10/26/15 23:48
# 8      815719234    False   finalized                   3     10/27/15 1:52
# 9      815719235    False   finalized                   3     10/27/15 1:49
# 10     815719236    False   finalized                   3    10/26/15 23:17
# 11     815719237    False   finalized                   3    10/26/15 22:33
# 12     815719238    False   finalized                   3    10/26/15 22:20
# 13     815719239    False   finalized                   3    10/26/15 23:29
# 14     815719240    False   finalized                   3     10/27/15 1:29
# 15     815719241    False   finalized                   3     10/27/15 1:50
# 16     815719242    False   finalized                   3    10/26/15 23:43
# 17     815719243    False   finalized                   3    10/26/15 22:50
# 18     815719244    False   finalized                   3     10/27/15 1:42
# 19     815719245    False   finalized                   3    10/26/15 22:19
# 20     815719246    False   finalized                   3     10/27/15 1:21
# 21     815719247    False   finalized                   3     10/27/15 0:09
# 22     815719248    False   finalized                   3    10/26/15 22:47
# 23     815719249    False   finalized                   3     10/27/15 1:34
# 24     815719250    False   finalized                   3    10/26/15 23:01
# 25     815719251    False   finalized                   3    10/26/15 22:54
# 26     815719252    False   finalized                   3    10/26/15 22:24
# 27     815719253    False   finalized                   3     10/27/15 1:22
# 28     815719254    False   finalized                   3    10/26/15 23:31
# 29     815719255    False   finalized                   3     10/27/15 1:46
# ...          ...      ...         ...                 ...               ...
# 20020  815754293     True      golden                 260               NaN
# 20021  815754330     True      golden                 259               NaN
# 20022  815754362     True      golden                 247               NaN
# 20023  815754554     True      golden                 254               NaN
# 20024  815754614     True      golden                 235               NaN
# 20025  815754750     True      golden                 245               NaN
# 20026  815755076     True      golden                 245               NaN
# 20027  815755206     True      golden                 231               NaN
# 20028  815755336     True      golden                 274               NaN
# 20029  815755512     True      golden                 246               NaN
# 20030  815755552     True      golden                 273               NaN
# 20031  815755604     True      golden                 242               NaN
# 20032  815755689     True      golden                 260               NaN
# 20033  815755763     True      golden                 239               NaN
# 20034  815755825     True      golden                 264               NaN
# 20035  815755887     True      golden                 270               NaN
# 20036  815756011     True      golden                 264               NaN
# 20037  815756103     True      golden                 259               NaN
# 20038  815756269     True      golden                 237               NaN
# 20039  815756332     True      golden                 227               NaN
# 20040  815756417     True      golden                 253               NaN
# 20041  815756542     True      golden                 252               NaN
# 20042  815756642     True      golden                 212               NaN
# 20043  815756700     True      golden                 240               NaN
# 20044  815756767     True      golden                 227               NaN
# 20045  815757572     True      golden                 259               NaN
# 20046  815757681     True      golden                 248               NaN
# 20047  815757830     True      golden                 264               NaN
# 20048  815757921     True      golden                 250               NaN
# 20049  815757985     True      golden                 249               NaN
#
#         gender  gender:confidence profile_yn  profile_yn:confidence  \
# 0         male             1.0000        yes                    1.0
# 1         male             1.0000        yes                    1.0
# 7                            NaN                          NaN
# 8                            NaN                          NaN
# 9           Nottingham, England.                    Amsterdam
# 10                      New York       Atlantic Time (Canada)
# 11                           NaN   Pacific Time (US & Canada)
# 12                           NaN       Atlantic Time (Canada)
# 13                America Credit   Pacific Time (US & Canada)
# 14                row b seat 104       Atlantic Time (Canada)
# 15                           NaN                          NaN
# 16                           NaN                      Arizona
# 17                       Glasgow                       London
# 18                           NaN                          NaN
# 19                           NaN                          NaN
# 20      St. John's, Newfoundland                          NaN
# 21                Port-au-Prince                      Arizona
# 22                           NaN                          NaN
# 23                     Tampa, FL                       London
# 24          University of Surrey                    Amsterdam
# 25                    Edmond, OK                          NaN
# 26                           ksa   Pacific Time (US & Canada)
# 27                           NaN   Eastern Time (US & Canada)
# 28                           NaN   Central Time (US & Canada)
# 29           Icon? Aogiri Penta.   Pacific Time (US & Canada)
# ...                          ...                          ...
# 20020              Mark Donoghue                          NaN
# 20021  SnapChat  DaeMontana103rd       Atlantic Time (Canada)
# 20022                        NaN                          NaN
# 20023                        NaN                          NaN
# 20024                New Zealand                     Auckland
# 20025   Shropshire and Mid Wales                          NaN
# 20026                     GY, UK                   Casablanca
# 20027                        NaN                          NaN
# 20028                        NaN   Pacific Time (US & Canada)
# 20029              New York, USA                          NaN
# 20030      Greater Washington DC       Atlantic Time (Canada)
# 20031                    Houston                          NaN
# 20032                        NaN                        Quito
# 20033                     brazil                          NaN
# 20034                 Raleigh NC   Eastern Time (US & Canada)
# 20035    Raleigh, North Carolina       Atlantic Time (Canada)
# 20036                  Yorkshire                          NaN
# 20037               Brooklyn, NY   Eastern Time (US & Canada)
# 20038                        NaN                          NaN
# 20039                        NaN                          NaN
# 20040             Houston, Texas   Central Time (US & Canada)
# 20041                   Colorado  Mountain Time (US & Canada)
# 20042                  Miami, FL   Eastern Time (US & Canada)
# 20043            Chertsey Bridge                          NaN
# 20044                        NaN                          NaN
# 20045                 Verona ªÁ                          NaN
# 20046            Kansas City, MO                          NaN
# 20047             Lagos Nigeria                           NaN
# 20048         Texas Hill Country                          NaN
# 20049                        NaN                          NaN
#
# [20050 rows x 26 columns]

# %%
"""
Из сырой выборки оставляем только объкты, где пол пользователя известен наверняка, профайл точно существует 
Избавляемся от всех параметров кроме текстов и меток классов: text, description, gender
Отбрасываем объекты с пропущенными значениями
"""

df = df_raw.loc[(df_raw['gender:confidence'] == 1.0) & (df_raw['profile_yn'] == 'yes') & (df_raw['profile_yn:confidence'] == 1.0)][['gender', 'text', 'description']].dropna()
df
# Out:
#        gender                                               text  \
# 0        male  Robbie E Responds To Critics After Win Against...
# 1        male  ÛÏIt felt like they were my friends and I was...
# 3        male  Hi @JordanSpieth - Looking at the url - do you...
# 4      female  Watching Neighbours on Sky+ catching up with t...
# 5      female  Ive seen people on the train with lamps, chair...
# 6       brand  @BpackEngineer Thank you for your patience whi...
# 7        male  Gala Bingo clubs bought for å£241m: The UK's l...

# 3      Mobile guy.  49ers, Shazam, Google, Kleiner Pe...
# 4      Ricky Wilson The Best FRONTMAN/Kaiser Chiefs T...
# 5                                     you don't know me.
# 6      A global marketplace for images, videos and mu...
# 7        The secret of getting ahead is getting started.
# 8             Pll Fan // Crazy about MCD // Ramen is bae
# 9      Renaissance art historian, University of Notti...
# 11                         highly extraordinary auctions
# 13     Come join the fastest blog network online toda...
# 16                                            JMKM_Òü
# 17     Over enthusiastic F1 fan.  Model collector, mu...
# 20     Artisan specializing in paper mache, print-mak...
# 21             He bled and died to take away my sins ÛÊ
# 22                                          union j xxxx
# 23                             You had me from the start
# 24                         BSc economics graduate  #COYS
# 25     Wife to my Coach. Mom to my eight troops. Foll...
# 28                   My Dms closed. | Sc: Dear_Moonshine
# 30     Breaking industry news for people who believe ...
# 31     Award Winning Author of the paranormal Romance...
# 32     self-proclaimed princess and occasional pain i...
# 33     K-Smooty~I drink alot. Could be worse. I'm scr...
# 34     Everything you need to find a job and keep it!...
# 35     Free Ma Bros #EBK #OTR #Real300 !\n\nAll I Kno...
# 36     Our nationÛªs leading voice for #ChildCare. A...
# 37                          penn state alum #classof2015
# 38     mirage homage...\ncapri eternal...\nhopeless r...
# 39     Lover of Women, Dogs/cats (dogs), Movies, Comi...
# ...                                                  ...
# 19996  607. Money in the making. Take it a day at a t...
# 19997  I can quote (Insert movie) better than you and...
# 19999                               Everything Winnipeg.
# 20002  Official Twitter account of The Football Assoc...
# 20004  Comedian / Writer / @RabbleTV Broadcaster & Ho...
# 20007                                  nottingham//OVOXO
# 20009                              calu '18 | Delta Zeta
# 20010  // giving; showing concern for humanity; chari...
# 20014  Award winning actor, Vocalist/Songwriter/Guita...
# 20015                                   I like to write.
# 20018  Research fellow @ceidotorg. Transport and urba...
# 20019  Averett Football #1 john 3:16 God,Family,Football
# 20020  PACIFIC VICTORY ROLL website - #RAAF & #RNZAF ...
# 20021                                  Camden, Nj single
# 20022                    come over let me blow your mind
# 20026  Freelance @Halo writer, with work appearing on...
# 20028                                           **sigh**
# 20030  Crowdsourcing #Innovation! The FINND connects ...
# 20032  Amicable IT person. Self indulgent writer. Som...
# 20034  Where Raleigh's dynamic leaders come to connec...
# 20035  25. love my friends & family. the color pink. ...
# 20037  Typographer and typographic consultant, co-fou...
# 20039          You can find me where the wild things are
# 20041  When families go through divorce, it's helpful...
# 20043  Head Chef, Chez Bruce. Loves Cars and Bicycles...
# 20044                       I Love Me...Myself....&....I
# 20045                                               (rp)
# 20046  Whatever you like, it's not a problem at all. ...
# 20047  #TeamBarcelona ..You look lost so you should f...
# 20049                     Teamwork makes the dream work.
#
# [11845 rows x 3 columns]

# %%
df.gender.unique()
# Out:
# array(['male', 'female', 'brand', 'unknown'], dtype=object)

# %%
# оставляем только муж/жен
df = df.loc[~df['gender'].isin(['unknown', 'brand'])]
df.gender.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8766 entries, 0 to 20049
# Data columns (total 3 columns):
# gender         8766 non-null object
# text           8766 non-null object
# description    8766 non-null object
# dtypes: object(3)
# memory usage: 273.9+ KB

# %%
df.describe()
# Out:
#         gender                                               text  \
# count     8766                                               8766
# unique       2                                               8727
# top     female  Build a Transforming Workbench, Desk, and Stor...
# freq      4616                                                 11
#
#                                               description
# count                                                8766
# unique                                               8454
# top     'Cos even an old girl's best friend is still h...
# freq                                                   18

# %%
# балансировка классов в целом ок
class_balance = df.groupby('gender').count()
class_balance
# Out:
#         text  description
# gender
# female  4616         4616
# male    4150         4150

# %%
# (pie chart) визуализация балансировки классов 
import matplotlib.pyplot as plt
# %matplotlib inline  

labels = list(class_balance.index.values)
sizes = class_balance.text

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# объединение фичей text и description в один документ 
df = df.assign(text = df['text'].map(str) + df['description'])
df = df.drop(['description'], axis=1).reset_index(drop=True)
df
# Out:
#       gender                                               text
# 0       male  Robbie E Responds To Critics After Win Against...
# 1       male  ÛÏIt felt like they were my friends and I was...
# 2       male  Hi @JordanSpieth - Looking at the url - do you...
# 3     female  Watching Neighbours on Sky+ catching up with t...
# 4     female  Ive seen people on the train with lamps, chair...
# 5       male  Gala Bingo clubs bought for å£241m: The UK's l...
# 6     female  @_Aphmau_ the pic defines all mcd fangirls/fan...
# 7     female  @Evielady just how lovely is the tree this yea...
# 8     female  @giannaaa28 lmao _Ù÷â_Ù÷â dude I'm hella scare...
# 9       male  @coolyazzy94 Ditto - I'm still learning the fa...
# 10    female  @CraftYear2015 @isabelpascual thank you for th...
# 11    female  All the girls went to sleep and the guys just ...
# 12    female  @ChrisAOfficial I'm on the right side_Ù÷âÏÎ_Ù...
# 13      male  YALL LMFAOO RIGHT WHEN THE CHORUS CAME ON, A T...
# 14      male  James Bond premier night at the @Everymancinem...
# 15    female  @SydnieJR except once the Hallmark movies star...
# 16    female  You leave the group chat for more than 2 mins ...
# 17      male  All the #magic in Hath No FURY is based on REA...
# 18    female  Me the week of Brandon's birthday: there's no ...
# 19      male  And got more yards AND points than the Jets ga...
# 20      male  Did Alot Up In The Past Ion Wont BackFree Ma B...
# 21    female  This boy was on the El wit his 3 daughters and...
# 22      male  @TheRiddler109 @CNN I mean it's not like Mains...
# 23      male  How many followers do you get everyday? I got ...
# 24      male  @kbonimtetezi mheshimiwa travellers along that...
# 25      male  Greenville Thursday. Yall holla you need anyth...
# 26    female  @MarkHicks1204 I went to the wrong Nandos but ...
# 27      male  @AndyRobsonTips Cardiff or drew with the over ...
# 28    female  VIDEO: James Bond Spectre world premiere: Afte...
# 29      male  Best thing about having an audition on the wes...
# ...      ...                                                ...
# 8736    male  Getting a superstar is a means, not the end go...
# 8737    male  The (rather thin) analysis of the federal elec...
# 8738  female  I constantly search the radio for hello, hotli...
# 8739    male  Processed meat is bad for you?!?! Well fuck me...
# 8740  female  Nothing like slipping at school running to you...
# 8741    male  Seriously love Trent and Justin. Would do anyt...
# 8742    male  One person can look at you like your the most ...
# 8743  female  These 24 Wedding Photobombs Made The Bride And...
# 8744    male  @TheFalcoholic is like the mailman... Because ...
# 8745  female  its for the best i hate 2/4 people in this hou...
# 8746  female  The day before the appointment to get my car i...
# 8747  female  @leedsparadise his name is Tapsi and he's the ...
# 8748    male  @scttpilgrim ive superseded tumblr and pintere...
# 8749  female  You can fall in love many times with many diff...
# 8750    male  @ebwashington @binarybits OEM-owned Car2Go. OE...
# 8751    male  @kass_xo was it really that funny lol and how ...
# 8752    male  And Yes Im Toting Catch Em Without My Strap &a...
# 8753    male  I think I'm going to move to Colorado for the ...
# 8754    male  Still looking for the free bar https://t.co/Wi...
# 8755  female  @lmaokaylinx @charlieputh but then i opened th...
# 8756    male  @legobutts you can do quests and kill stuff wh...
# 8757  female  Beetlejuice is the perfect Halloween movie!!!!...
# 8758    male  @TrentWalton @oguzbilgic Spell it out in all-c...
# 8759  female  Especially when all you do is the best you can...
# 8760    male  Game faggot and venison loin, crisp spelt and ...
# 8761  female  Need A Ride Home From Practice _Ù÷Ô_Ù÷Ô_Ù÷ÔAnd...
# 8762  female  @lookupondeath ...Fine, and I'll drink tea too...
# 8763    male  Greg Hardy you a good player and all but don't...
# 8764    male  You can miss people and still never want to se...
# 8765  female  I think for my APUSH creative project I'm goin...
#
# [8766 rows x 2 columns]

# %%
# X и y для test_train_split

from joblib import Parallel, delayed
import numpy as np
import gensim

def tokenize_text(i):
    # convert a document into a list of lowercase tokens, ignoring tokens that are too short or too long
    return gensim.utils.simple_preprocess(str(df.iloc[i]['text']), deacc=True)

X = np.array([Parallel(n_jobs=4)(delayed(tokenize_text)(i) for i in range(df.shape[0]))]).reshape((df.shape[0]))
y = np.array([(lambda i: df.iloc[i]['gender'])(i)for i in range(df.shape[0])])
# Out:
# 2018-08-22 01:21:00,764 : INFO : 'pattern' package not found; tag filters are not available for English

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# лейблы вместо текста для целевой переменной 
enc = preprocessing.LabelEncoder()
y = enc.fit_transform(y)
# TODO: не забыть сделать inverse_transform: enc.inverse_transform(y)

# Тестовая и контрольная выборки, random_state for reproducible research 
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# ---конец предобработки--- #

# %%
enc_mapping = dict(zip(enc.classes_, enc.transform(enc.classes_)))

# %% [markdown]
# ### 3. Feature Engineering
#
# Теперь необходимо привести текст каждого объекта к векторной (матричной) форме.
#
# <br>Найдем векторы слов Word2vec для каждого объекта и найдем их среднее арифметическое учитывая веса TF-IDF.
#
# TF-IDF: https://ru.wikipedia.org/wiki/TF-IDF (сравнительно простая модель, частота слова из документа вычисляется прямопропорционально числу вхождения слова в этот документ и обратнопропорционально числу вхождения слова в corpus (все док-ты коллекции).
# <br><br>Word2Vec: https://ru.wikipedia.org/wiki/Word2vec (учитывает окружение слова, хотя порядок слов в окружении алгоритм не учитывает)

# %%
# TFIDF - веса слов 

from sklearn.feature_extraction.text import TfidfVectorizer  
from sklearn.feature_extraction import text

'''
Препроцессинг прошел не идеально: есть части языковых конструкций (ll - will, don - don't и т.д.),
часто употребляемые прилагательные (размер, восклицание и т.д.),
синонимы (ig - instagram и т.д.) и так далее. Список стоп слов был частично расширен вручную так, 
чтобы нерелевантные не лезли в топ25
'''

stop_words = ["just", "like", "don", "https", "best", "want", "know", "good", "ve", "a_u", "make", "got", "new", "ªa", "need", "im", "http", "think", "ll", "need", "u_", "say", "com", "great", "really", "shit", "say", "going", "little", "right", "follow", "let", "today", "thank", "live", "things", "god", "come", "year", "way", "day", "love", "life", "wanna", "big", "free", "big", "better", "look", "gonna", "makes", "time", "fuck", "tweets", "amp", "lover", "lot", "real", "instagram", "thanks", "thing", "did", "old", "people", "trying", "ii"]
stop_words_extended = text.ENGLISH_STOP_WORDS.union(stop_words)

def dummy(doc_text):
    return doc_text

# word level tf-idf
tfidf_mod = TfidfVectorizer(
    analyzer='word', 
    strip_accents='unicode',
    norm="l2", # евклидова норма=1
    #ngram_range=(1, 2), # unigrams + bigrams
    sublinear_tf=True, 
    tokenizer=dummy, 
    preprocessor=dummy,
    stop_words=stop_words_extended)

tfidf_mod.fit(X)

X_tfidf = tfidf_mod.transform(X)

# Sparse tf-idf-weighted document-term matrix [n_samples, n_features]

#xtrain_tfidf, xtest_tfidf = tfidf_mod.transform(X_train), tfidf_mod.transform(X_test) 
X_tfidf = tfidf_mod.transform(X)

# convert to dense 
tfidf_index_value = {i[1]:i[0] for i in tfidf_mod.vocabulary_.items()}

def sparse_to_dense(sparse):
    dense = []
    for row in sparse:
        dense.append({tfidf_index_value[col]:val for (col,val) in zip(row.indices,row.data)})
    return dense
    
#xtrain_tfidf_dense, xtest_tfidf_dense = sparse_to_dense(xtrain_tfidf), sparse_to_dense(xtest_tfidf)
x_tfidf_dense = sparse_to_dense(X_tfidf)
features = tfidf_mod.get_feature_names()

# %%
# top words per gender 

def top_tfidf(row_id, feats, top_n=10):
    ''' Возвращает top_n=10 слов в порядке убывания их tfidf scores '''
    top_ids = np.argsort(row_id)[::-1][:top_n]
    top_feats = [(feats[i], row_id[i]) for i in top_ids]
    top_tfidf_df = pd.DataFrame(top_feats)
    top_tfidf_df.columns = ['feature', 'tfidf_score']
    top_tfidf_df.sort_values('tfidf_score', inplace=True)
    return top_tfidf_df

def top_feats_in_doc(X, feats, row, top_n=10):
    ''' Возвращает top_n=10 фичей в документе (строка матрицы) '''
    row = np.squeeze(X[row].toarray())
    return top_tfidf_feats(row, feats, top_n)

def top_mean_feats(X, feats, X_row_ids=None, min_tfidf=0.1, top_n=10):
    ''' Возвращает top_n самых важных фичей из строк X_row_ids '''
    if X_row_ids:
        X_ = X[X_row_ids].toarray()
    else:
        X_ = X.toarray()

    X_[X_ < min_tfidf] = 0
    tfidf_means = np.mean(X_, axis=0)
    return top_tfidf(tfidf_means, feats, top_n)

def top_feats_by_label(X, y, feats, min_tfidf=0.1, top_n=10):
    ''' Возвращает список датафреймов с top_n для каждого из лейблов из y '''
    dfs = {} # dict для датафреймов, ключами станут лейблы 
    lbls = np.unique(y) # все лейблы целевой переменной 
    for label in lbls:
        ids = np.where(y==label) # идентификаторы нужных строк для текущего лейбла 
        feats_df = top_mean_feats(X, feats, ids, min_tfidf=min_tfidf, top_n=top_n)
        feats_df.label = label
        dfs[label] = feats_df
    return dfs

def plot_top_feats_by_label(dfs):
    ''' Строит лежачие столбчатые диаграммы по датафреймам от top_feats_by_label '''
    fig = plt.figure(figsize=(12, 9), facecolor="w")
    x = np.arange(len(dfs[0]))
    colors = ['r', 'g', 'y', 'b']
    for i, df in dfs.items():
        ax = fig.add_subplot(1, len(dfs), i+1)
        
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)
        ax.set_frame_on(False)
        
        ax.get_xaxis().tick_bottom()
        ax.get_yaxis().tick_left()
        ax.set_xlabel("tfidf (среднее по классу)", labelpad=16, fontsize=12, color="k")
        ax.set_title("Класс = " + str(enc.inverse_transform(df.label)), fontsize=15)
        ax.ticklabel_format(axis='x', style='plain', scilimits=(-2,2))
        ax.barh(x, df.tfidf_score, align='center', color=colors[i])
        ax.set_yticks(x)
        ax.set_ylim([-1, x[-1]+1])
        yticks = ax.set_yticklabels(df.feature)
        plt.subplots_adjust(bottom=0.1, right=1, left=0.15, top=0.7, wspace=0.5)
    plt.show()
    
plot_top_feats_by_label(top_feats_by_label(X_tfidf, y, features, top_n=30))
# Out:
# /home/greg/anaconda3/envs/py36_2/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/greg/anaconda3/envs/py36_2/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
# Word2Vec

# обучаем словарь Word2Vec на коллекции документов, каждое слово теперь представлено в виде вектора 
# size => кол-во возможных значений gender (2)
w2v_mod = gensim.models.Word2Vec(X, workers=4, min_count=1)

'''bigram_model = Phrases(unigram_sentences)

for unigram_sentence in unigram_sentences:                
            bigram_sentence = u' '.join(bigram_model[unigram_sentence])
            
# gensim for bigrams | TODO: сделать и подружить с tfidf биграммами если останется время 
'''
# Out:
# 2018-08-22 01:21:09,418 : INFO : collecting all words and their counts
# 2018-08-22 01:21:09,419 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-08-22 01:21:09,484 : INFO : collected 37694 word types from a corpus of 236963 raw words and 8766 sentences
# 2018-08-22 01:21:09,485 : INFO : Loading a fresh vocabulary
# 2018-08-22 01:21:09,635 : INFO : effective_min_count=1 retains 37694 unique words (100% of original 37694, drops 0)
# 2018-08-22 01:21:09,636 : INFO : effective_min_count=1 leaves 236963 word corpus (100% of original 236963, drops 0)
# 2018-08-22 01:21:09,749 : INFO : deleting the raw counts dictionary of 37694 items
# 2018-08-22 01:21:09,750 : INFO : sample=0.001 downsamples 36 most-common words
# 2018-08-22 01:21:09,751 : INFO : downsampling leaves estimated 197473 word corpus (83.3% of prior 236963)
# 2018-08-22 01:21:09,862 : INFO : estimated required memory for 37694 words and 100 dimensions: 49002200 bytes
# 2018-08-22 01:21:09,863 : INFO : resetting layer weights
# 2018-08-22 01:21:10,261 : INFO : training model with 4 workers on 37694 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-08-22 01:21:10,446 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-08-22 01:21:10,447 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-08-22 01:21:10,453 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-08-22 01:21:10,459 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-08-22 01:21:10,459 : INFO : EPOCH - 1 : training on 236963 raw words (197464 effective words) took 0.2s, 1049893 effective words/s
# 2018-08-22 01:21:10,649 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-08-22 01:21:10,654 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-08-22 01:21:10,658 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-08-22 01:21:10,659 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-08-22 01:21:10,659 : INFO : EPOCH - 2 : training on 236963 raw words (197502 effective words) took 0.2s, 1034111 effective words/s
# 2018-08-22 01:21:10,888 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-08-22 01:21:10,906 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-08-22 01:21:10,910 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-08-22 01:21:10,914 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-08-22 01:21:10,917 : INFO : EPOCH - 3 : training on 236963 raw words (197200 effective words) took 0.2s, 808949 effective words/s
# 2018-08-22 01:21:11,241 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-08-22 01:21:11,256 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-08-22 01:21:11,273 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-08-22 01:21:11,274 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-08-22 01:21:11,275 : INFO : EPOCH - 4 : training on 236963 raw words (197431 effective words) took 0.4s, 563860 effective words/s
# 2018-08-22 01:21:11,556 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-08-22 01:21:11,557 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-08-22 01:21:11,562 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-08-22 01:21:11,563 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-08-22 01:21:11,564 : INFO : EPOCH - 5 : training on 236963 raw words (197303 effective words) took 0.3s, 723741 effective words/s
# 2018-08-22 01:21:11,565 : INFO : training on a 1184815 raw words (986900 effective words) took 1.3s, 756847 effective words/s
# "bigram_model = Phrases(unigram_sentences)\n\nfor unigram_sentence in unigram_sentences:                \n            bigram_sentence = u' '.join(bigram_model[unigram_sentence])\n            \n# gensim for bigrams | TODO: сделать и подружить с tfidf биграммами если останется время \n"

# %%
# Теперь, имея в распоряжении веса TFIDF и соответствующие векторные формы слов от gensim, 
# вычисляем репрезентативный вектор для каждого объекта обучающей и тестовой выборок 

def w2v_weighted(corpus):
    w2v_w = []
    for doc in corpus:
        weighted_terms = []
        for key, value in doc.items():
            weighted_term = w2v_mod.wv[key] * value
            weighted_terms.append(weighted_term)
        weighted_mean = np.array((weighted_terms)).mean(axis=0)
        w2v_w.append(weighted_mean)
    return w2v_w
    
            
            
#xtrain_w2v, xtest_w2v = w2v_weighted(xtrain_tfidf_dense), w2v_weighted(xtest_tfidf_dense)
X_w2v = w2v_weighted(x_tfidf_dense)
X_w2v[0]
# Out:
# array([ 1.53002720e-02, -2.09088307e-02,  1.83647051e-02, -9.04193521e-03,
#        -3.01820766e-02, -7.84364250e-03, -2.16774177e-02,  1.62330121e-02,
#         2.67125890e-02, -1.25881443e-02, -9.95709375e-03,  3.24000567e-02,
#        -3.00830174e-02,  2.20821425e-02,  1.46686137e-02,  1.14039527e-02,
#         1.17559237e-02, -4.13481658e-03,  3.85534804e-04,  3.01605766e-03,
#        -8.55141785e-03, -4.03440138e-03, -4.07680497e-03,  6.33392250e-03,
#         9.84825939e-03, -1.09202741e-02,  1.50309168e-02,  7.63303693e-03,
#         4.03274922e-03,  1.05172284e-02, -1.13079417e-02,  3.58335599e-02,
#        -1.97327156e-02,  3.56855290e-03,  5.43334428e-03, -1.22110639e-02,
#         5.85769769e-03, -1.76267922e-02, -1.37144960e-02,  5.34100691e-03,
#        -1.73772871e-02, -2.21284982e-02,  1.60189644e-02,  3.61152329e-02,
#        -8.30435660e-03,  3.20433377e-04,  1.27802910e-02, -1.14540504e-04,
#         1.57412654e-03, -1.57026369e-02,  3.61909857e-04, -9.09247529e-03,
#         1.73955644e-03, -1.70143414e-02, -1.57202072e-02, -4.67608357e-03,
#        -1.74147449e-03,  7.40145473e-03, -1.20977340e-02,  3.12875700e-03,
#        -7.89113063e-03,  1.76396668e-02, -8.03302042e-03,  1.46634467e-02,
#         1.67056397e-02, -1.34911444e-02, -1.00527005e-02,  8.92196968e-03,
#         9.00711631e-04,  1.16677666e-02,  1.02193244e-02, -9.14901774e-03,
#         8.24252050e-03,  3.08748484e-02,  1.05668670e-02,  1.12772333e-02,
#         1.55997360e-02, -4.30470286e-03,  3.80490022e-03, -1.16792191e-02,
#        -9.69816372e-03, -8.19671527e-03, -1.17463944e-02,  9.23358748e-05,
#         8.61135195e-04,  4.46360419e-03,  5.23610599e-03, -8.96454509e-03,
#         1.29026566e-02, -2.89113093e-02, -1.30691268e-02, -4.73728776e-03,
#         1.58203002e-02,  8.21913127e-03, -8.01644940e-03,  3.63456365e-03,
#         1.98637713e-02, -8.46591219e-03,  2.42662001e-02, -1.40805375e-02],
#       dtype=float32)

# %%
# вместо нормализации вписываем в [0, 1] для SVM (отрицательные не принимает)

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(X_w2v)
#xtrain_w2v_sc = scaler.transform(xtrain_w2v)
#xtest_w2v_sc = scaler.transform(xtest_w2v)
X_w2v_sc = scaler.transform(X_w2v)
X_w2v_sc
# Out:
# array([[0.03273493, 0.97201424, 0.02204878, ..., 0.83267992, 0.02223806,
#         0.96499097],
#        [0.08234845, 0.92938043, 0.04823737, ..., 0.82030753, 0.04659854,
#         0.91567637],
#        [0.03892717, 0.96693573, 0.02270751, ..., 0.83402518, 0.0227276 ,
#         0.9579275 ],
#        ...,
#        [0.05023181, 0.95489972, 0.03380058, ..., 0.82621698, 0.03372497,
#         0.94465169],
#        [0.09869367, 0.90486975, 0.09446653, ..., 0.76703806, 0.09749243,
#         0.8982299 ],
#        [0.11943401, 0.88569249, 0.09828126, ..., 0.77436481, 0.09815025,
#         0.86924092]])

# %%
# PCA

from sklearn.decomposition import PCA

pca = PCA(n_components=2)
principalComponents = pca.fit_transform(X_w2v)
principalDf = pd.DataFrame(data=principalComponents, columns=['pc1', 'pc2'])
finalDf = pd.concat([principalDf, pd.DataFrame(y, columns=['target'])], axis = 1)

fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = [0, 1]
colors = ['r', 'g']
for target, color in zip(targets, colors):
    indicesToKeep = finalDf['target'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'pc1'], finalDf.loc[indicesToKeep, 'pc2'], c = color, s = 150, alpha=0.2)
ax.legend(enc.inverse_transform(targets))
ax.grid()
# Out:
# /home/greg/anaconda3/envs/py36_2/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
# TSNE

from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, verbose=2, n_iter=300)
principalComponents = tsne.fit_transform(X_w2v)

principalDf = pd.DataFrame(data=principalComponents, columns=['pc1', 'pc2'])
finalDf = pd.concat([principalDf, pd.DataFrame(y, columns=['target'])], axis = 1)

fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component t-SNE', fontsize = 20)
targets = [0, 1]
colors = ['r', 'g']
for target, color in zip(targets, colors):
    indicesToKeep = finalDf['target'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'pc1'], finalDf.loc[indicesToKeep, 'pc2'], c = color, s = 10, alpha=0.2)
ax.legend(enc.inverse_transform(targets))
ax.grid()
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 8766 samples in 0.034s...
# [t-SNE] Computed neighbors for 8766 samples in 2.081s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 8766
# [t-SNE] Computed conditional probabilities for sample 2000 / 8766
# [t-SNE] Computed conditional probabilities for sample 3000 / 8766
# [t-SNE] Computed conditional probabilities for sample 4000 / 8766
# [t-SNE] Computed conditional probabilities for sample 5000 / 8766
# [t-SNE] Computed conditional probabilities for sample 6000 / 8766
# [t-SNE] Computed conditional probabilities for sample 7000 / 8766
# [t-SNE] Computed conditional probabilities for sample 8000 / 8766
# [t-SNE] Computed conditional probabilities for sample 8766 / 8766
# [t-SNE] Mean sigma: 0.005076
# [t-SNE] Computed conditional probabilities in 0.649s
# [t-SNE] Iteration 50: error = 93.2254486, gradient norm = 0.0268717 (50 iterations in 13.445s)
# [t-SNE] Iteration 100: error = 74.9961624, gradient norm = 0.0054289 (50 iterations in 12.760s)
# [t-SNE] Iteration 150: error = 71.6611557, gradient norm = 0.0027438 (50 iterations in 12.074s)
# [t-SNE] Iteration 200: error = 70.2746429, gradient norm = 0.0016023 (50 iterations in 11.882s)
# [t-SNE] Iteration 250: error = 69.5152130, gradient norm = 0.0013456 (50 iterations in 11.249s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 69.515213
# [t-SNE] Iteration 300: error = 2.2243211, gradient norm = 0.0013034 (50 iterations in 12.017s)
# [t-SNE] Error after 300 iterations: 2.224321
# /home/greg/anaconda3/envs/py36_2/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %% [markdown]
# Классы разделимы довольно плохо, скорее всего сказывается сравнительно малый размер данных

# %% [markdown]
# ### 4. Модели

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
import seaborn as sns

def models_accuracy(X, y, data_eng_method):
    models = [
        RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0),
        LinearSVC(random_state=0),
        MultinomialNB(),
        LogisticRegression(random_state=0)]

    CV = 5
    cv_df = pd.DataFrame(index=range(CV * len(models)))
    entries = []
    for model in models:
        model_name = model.__class__.__name__
        accuracies = cross_val_score(model, X, y, scoring='accuracy', cv=CV)
        for fold_idx, accuracy in enumerate(accuracies):
            entries.append((model_name, fold_idx, accuracy))
    cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])

    sns.boxplot(x='model_name', y='accuracy', data=cv_df)
    sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
                  size=8, jitter=True, edgecolor="gray", linewidth=2)
    plt.title(data_eng_method)
    plt.show()
    
    return cv_df
              
models_accuracy(X_tfidf, y, "TFIDF")
# Out:
# /home/greg/anaconda3/envs/py36_2/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
#                 model_name  fold_idx  accuracy
# 0   RandomForestClassifier         0  0.530787
# 1   RandomForestClassifier         1  0.528808
# 2   RandomForestClassifier         2  0.526526
# 3   RandomForestClassifier         3  0.528808
# 4   RandomForestClassifier         4  0.527667
# 5                LinearSVC         0  0.650513
# 6                LinearSVC         1  0.671420
# 7                LinearSVC         2  0.657730
# 8                LinearSVC         3  0.668568
# 9                LinearSVC         4  0.667998
# 10           MultinomialNB         0  0.660775
# 11           MultinomialNB         1  0.694809
# 12           MultinomialNB         2  0.674843
# 13           MultinomialNB         3  0.667998
# 14           MultinomialNB         4  0.681689
# 15      LogisticRegression         0  0.667047
# 16      LogisticRegression         1  0.696520
# 17      LogisticRegression         2  0.664575
# 18      LogisticRegression         3  0.671991
# 19      LogisticRegression         4  0.674273

# %%
models_accuracy(X_w2v_sc, y, "Word2vec")
# Out:
#                 model_name  fold_idx  accuracy
# 0   RandomForestClassifier         0  0.591220
# 1   RandomForestClassifier         1  0.582430
# 2   RandomForestClassifier         2  0.585282
# 3   RandomForestClassifier         3  0.583001
# 4   RandomForestClassifier         4  0.588135
# 5                LinearSVC         0  0.599772
# 6                LinearSVC         1  0.586423
# 7                LinearSVC         2  0.581860
# 8                LinearSVC         3  0.578437
# 9                LinearSVC         4  0.604678
# 10           MultinomialNB         0  0.545610
# 11           MultinomialNB         1  0.521392
# 12           MultinomialNB         2  0.534512
# 13           MultinomialNB         3  0.526526
# 14           MultinomialNB         4  0.531660
# 15      LogisticRegression         0  0.591790
# 16      LogisticRegression         1  0.577867
# 17      LogisticRegression         2  0.580719
# 18      LogisticRegression         3  0.575585
# 19      LogisticRegression         4  0.596121

# %%
# настроить регуляризатор для w2v_weighted
# добавить pipeline с gridsearchcv
